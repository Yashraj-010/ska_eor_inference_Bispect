# %% [markdown]
# # Example notebook: Adding noise to a simulation

# %% [markdown]
# Authors: Adélie Gorce & Sambit Giri
#
# In this notebook, we give an example of how to load one of the simulation lightcone from the dataset and turn it into an observational lightcone including thermal noise and beam smoothing, for the AA* layout, with the help of `tools21cm`.

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
from astropy.cosmology import Planck18 as cos
from astropy import units, constants
# For noise calculations
import tools21cm as t2c

# %%
seed = 123456 # Choose your favorite number
np.random.seed(seed)

# %%
h = 0.6774

# %% [markdown]
# ## Load metadata and simulation

# %%
# Folder containing the simulations
# ddir = '/data/cluster/agorce/SKA_chapter_simulations/'
ddir = './SKA_chapter_simulations/' # This folder can be created inside the repository folder. It will be ignored during the git commit.
# File with fiducial lightcone
file = ddir+'Lightcone_FID_400_Samples.h5'

# %%
# pick realisation to load
i = np.random.randint(400)

# %%
# Read h5py file to obtain metadata
with h5py.File(file, 'r') as f:
    frequencies = f['frequencies'][...]  # frequencies along the lightcone
    redshifts = f['redshifts'][...]  # redshifts along the lightcone
    box_length = float(f['box_length'][0])/h  # Mpc
    ngrid = int(f['ngrid'][0])  # number of pixels along the sky patch
    nrand = int(f['nrealisations'][0])  # number of realisations for a given parameter set
    lc = f['brightness_lightcone'][i, ...]
nfreq = frequencies.size
print(f'Lightcone runs from z={redshifts.min():.2f} to z = {redshifts.max():.2f}, mean redshift {np.mean(redshifts):.2f}.')
# move los axis to match t2c
lc = np.moveaxis(lc, 0, 2)
# Out:
# Lightcone runs from z=8.82 to z = 9.33, mean redshift 9.07.

# %%
# The physical length along the line-of-sight (LoS) is different from the field-of-view (FoV).
# Below the list box_length_list should be provided to power spectrum calculator of tools21cm to take this into account.
cdists = cos.comoving_distance(redshifts)
box_length_los = (cdists.max()-cdists.min()).value
box_length_list = [box_length, box_length, box_length_los]

print(f'Box length = {box_length:.1f} (FoV) and {box_length_los:.1f} (LoS) Mpc.')
# Out:
# Box length = 295.2 (FoV) and 126.5 (LoS) Mpc.

# %%
# Pick a random redshift for plots
iz = np.random.randint(nfreq)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 5))
im = ax.imshow(
    t2c.subtract_mean_signal(lc, los_axis=2)[..., iz],
    extent=(0, box_length, 0, box_length),
    origin='lower', cmap='RdBu_r', aspect='auto',
    # vmin=-np.max(np.abs(lc[..., iz])), vmax=np.max(np.abs(lc[..., iz])),
    )
ax.set_xlabel(r'$x$ [Mpc]')
ax.set_ylabel(r'$y$ [Mpc]')
plt.colorbar(im, label=r'$\delta T_b$ [mK]')
ax.set_title(rf'Cosmological signal @ $z={redshifts[iz]:.1f}$')
fig.tight_layout()

# %% [markdown]
# ## Apply SKA AA* observational effects

# %% [markdown]
# This is the procedure also followed in `compute_statistic`. We compute noise maps for 1000 hours observations, split into 10 seconds intervals, 6 hours a day.

# %%
# SKA obs parameters
obs_time = 1000.  # hours
int_time = 10.  # seconds
total_int_time = 6.  # hours per day
declination = -30.0  # declination of the field in degrees
bmax = 2. * units.km  # km

# %% [markdown]
# Look at the $uv$ sampling for AA* layout

# %%
uv, Nant = t2c.get_uv_map(
                ncells=ngrid,                  # The number of cell used to make the image
                z=np.mean(redshifts),          # Redhsift of the slice observed
                subarray_type="AAstar",        # SKA layout
                total_int_time=total_int_time, # Observation per day in hours.
                int_time=int_time,             # Time period of recording the data in seconds.
                boxsize=box_length,            # Comoving size of the sky observed
                declination=declination,       # Declination angle defining the direction of observation
                )

x = np.linspace(0, box_length, ngrid)
plt.pcolormesh(x, x, np.log10(np.fft.fftshift(uv)))
# Out:
# AAstar contains 307 antennae.
# ENU -> ECEF -> XYZ
# Generating uv map from daily observations...
# Gridding uv tracks: 100%|██████████| 2160/2160 [00:15<00:00, 141.47it/s]
# ...done

# %%
# generate noise lightcone
noise_lc = t2c.noise_lightcone(
    ncells=ngrid,
    zs=redshifts,
    obs_time=obs_time,
    total_int_time=total_int_time,
    int_time=int_time,
    declination=declination,
    subarray_type="AAstar",
    boxsize=box_length,
    verbose=False,
    save_uvmap=ddir+'uvmap_AAstar.h5',  # save uv coverage to re-use for each realisation
    n_jobs=6,  # parallelisation
    checkpoint=16,  #  The code write data after checkpoint number of calculations.
)  # third axis is line of sight
# Out:
# Creating the uv maps.
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:   26.8s
# [Parallel(n_jobs=6)]: Done   2 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=6)]: Done   3 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=6)]: Done   4 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=6)]: Done   5 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=6)]: Done   6 out of  16 | elapsed:   28.0s remaining:   46.6s
# [Parallel(n_jobs=6)]: Done   7 out of  16 | elapsed:   44.8s remaining:   57.5s
# [Parallel(n_jobs=6)]: Done   8 out of  16 | elapsed:   46.9s remaining:   46.9s
# [Parallel(n_jobs=6)]: Done   9 out of  16 | elapsed:   47.2s remaining:   36.7s
# [Parallel(n_jobs=6)]: Done  10 out of  16 | elapsed:   47.2s remaining:   28.3s
# [Parallel(n_jobs=6)]: Done  11 out of  16 | elapsed:   47.6s remaining:   21.6s
# [Parallel(n_jobs=6)]: Done  12 out of  16 | elapsed:   47.7s remaining:   15.9s
# [Parallel(n_jobs=6)]: Done  13 out of  16 | elapsed:  1.0min remaining:   14.1s
# [Parallel(n_jobs=6)]: Done  14 out of  16 | elapsed:  1.1min remaining:    9.1s
# [Parallel(n_jobs=6)]: Done  16 out of  16 | elapsed:  1.1min finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=6)]: Done   2 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=6)]: Done   3 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=6)]: Done   4 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=6)]: Done   5 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=6)]: Done   6 out of  16 | elapsed:   20.5s remaining:   34.2s
# [Parallel(n_jobs=6)]: Done   7 out of  16 | elapsed:   36.1s remaining:   46.4s
# [Parallel(n_jobs=6)]: Done   8 out of  16 | elapsed:   39.4s remaining:   39.4s
# [Parallel(n_jobs=6)]: Done   9 out of  16 | elapsed:   40.1s remaining:   31.2s
# [Parallel(n_jobs=6)]: Done  10 out of  16 | elapsed:   40.1s remaining:   24.1s
# [Parallel(n_jobs=6)]: Done  11 out of  16 | elapsed:   40.7s remaining:   18.5s
# [Parallel(n_jobs=6)]: Done  12 out of  16 | elapsed:   41.1s remaining:   13.7s
# [Parallel(n_jobs=6)]: Done  13 out of  16 | elapsed:   53.8s remaining:   12.4s
# [Parallel(n_jobs=6)]: Done  14 out of  16 | elapsed:   56.8s remaining:    8.1s
# [Parallel(n_jobs=6)]: Done  16 out of  16 | elapsed:   57.8s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=6)]: Done   2 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=6)]: Done   3 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=6)]: Done   4 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=6)]: Done   5 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=6)]: Done   6 out of  16 | elapsed:   20.0s remaining:   33.3s
# [Parallel(n_jobs=6)]: Done   7 out of  16 | elapsed:   35.8s remaining:   46.1s
# [Parallel(n_jobs=6)]: Done   8 out of  16 | elapsed:   38.2s remaining:   38.2s
# [Parallel(n_jobs=6)]: Done   9 out of  16 | elapsed:   38.3s remaining:   29.8s
# [Parallel(n_jobs=6)]: Done  10 out of  16 | elapsed:   38.3s remaining:   23.0s
# [Parallel(n_jobs=6)]: Done  11 out of  16 | elapsed:   38.8s remaining:   17.6s
# [Parallel(n_jobs=6)]: Done  12 out of  16 | elapsed:   39.2s remaining:   13.1s
# [Parallel(n_jobs=6)]: Done  13 out of  16 | elapsed:   53.2s remaining:   12.3s
# [Parallel(n_jobs=6)]: Done  14 out of  16 | elapsed:   55.9s remaining:    8.0s
# [Parallel(n_jobs=6)]: Done  16 out of  16 | elapsed:   56.5s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=6)]: Done   2 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=6)]: Done   3 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=6)]: Done   4 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=6)]: Done   5 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=6)]: Done   6 out of  16 | elapsed:   19.2s remaining:   32.1s
# [Parallel(n_jobs=6)]: Done   7 out of  16 | elapsed:   37.7s remaining:   48.5s
# [Parallel(n_jobs=6)]: Done   8 out of  16 | elapsed:   38.2s remaining:   38.2s
# [Parallel(n_jobs=6)]: Done   9 out of  16 | elapsed:   38.3s remaining:   29.8s
# [Parallel(n_jobs=6)]: Done  10 out of  16 | elapsed:   38.8s remaining:   23.3s
# [Parallel(n_jobs=6)]: Done  11 out of  16 | elapsed:   39.3s remaining:   17.9s
# [Parallel(n_jobs=6)]: Done  12 out of  16 | elapsed:   40.4s remaining:   13.5s
# [Parallel(n_jobs=6)]: Done  13 out of  16 | elapsed:   56.0s remaining:   12.9s
# [Parallel(n_jobs=6)]: Done  14 out of  16 | elapsed:   56.1s remaining:    8.0s
# [Parallel(n_jobs=6)]: Done  16 out of  16 | elapsed:   57.2s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=6)]: Done   2 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=6)]: Done   3 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=6)]: Done   4 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=6)]: Done   5 tasks      | elapsed:   19.8s
# [Parallel(n_jobs=6)]: Done   6 out of  16 | elapsed:   21.2s remaining:   35.3s
# [Parallel(n_jobs=6)]: Done   7 out of  16 | elapsed:   36.8s remaining:   47.3s
# [Parallel(n_jobs=6)]: Done   8 out of  16 | elapsed:   37.0s remaining:   37.0s
# [Parallel(n_jobs=6)]: Done   9 out of  16 | elapsed:   38.0s remaining:   29.6s
# [Parallel(n_jobs=6)]: Done  10 out of  16 | elapsed:   38.5s remaining:   23.1s
# [Parallel(n_jobs=6)]: Done  11 out of  16 | elapsed:   38.9s remaining:   17.7s
# [Parallel(n_jobs=6)]: Done  12 out of  16 | elapsed:   40.0s remaining:   13.3s
# [Parallel(n_jobs=6)]: Done  13 out of  16 | elapsed:   54.7s remaining:   12.6s
# [Parallel(n_jobs=6)]: Done  14 out of  16 | elapsed:   55.9s remaining:    8.0s
# [Parallel(n_jobs=6)]: Done  16 out of  16 | elapsed:   56.5s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=6)]: Done   2 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=6)]: Done   3 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=6)]: Done   4 tasks      | elapsed:   19.8s
# [Parallel(n_jobs=6)]: Done   5 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=6)]: Done   6 out of  16 | elapsed:   20.1s remaining:   33.4s
# [Parallel(n_jobs=6)]: Done   7 out of  16 | elapsed:   37.8s remaining:   48.6s
# [Parallel(n_jobs=6)]: Done   8 out of  16 | elapsed:   37.9s remaining:   37.9s
# [Parallel(n_jobs=6)]: Done   9 out of  16 | elapsed:   37.9s remaining:   29.5s
# [Parallel(n_jobs=6)]: Done  10 out of  16 | elapsed:   38.5s remaining:   23.1s
# [Parallel(n_jobs=6)]: Done  11 out of  16 | elapsed:   39.1s remaining:   17.8s
# [Parallel(n_jobs=6)]: Done  12 out of  16 | elapsed:   39.6s remaining:   13.2s
# [Parallel(n_jobs=6)]: Done  13 out of  16 | elapsed:   54.5s remaining:   12.6s
# [Parallel(n_jobs=6)]: Done  14 out of  16 | elapsed:   54.7s remaining:    7.8s
# [Parallel(n_jobs=6)]: Done  16 out of  16 | elapsed:   55.2s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=6)]: Done   2 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=6)]: Done   3 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=6)]: Done   4 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=6)]: Done   5 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=6)]: Done   6 out of  16 | elapsed:   20.1s remaining:   33.6s
# [Parallel(n_jobs=6)]: Done   7 out of  16 | elapsed:   35.7s remaining:   45.9s
# [Parallel(n_jobs=6)]: Done   8 out of  16 | elapsed:   36.4s remaining:   36.4s
# [Parallel(n_jobs=6)]: Done   9 out of  16 | elapsed:   36.4s remaining:   28.3s
# [Parallel(n_jobs=6)]: Done  10 out of  16 | elapsed:   40.2s remaining:   24.1s
# [Parallel(n_jobs=6)]: Done  11 out of  16 | elapsed:   40.4s remaining:   18.4s
# [Parallel(n_jobs=6)]: Done  12 out of  16 | elapsed:   40.6s remaining:   13.5s
# [Parallel(n_jobs=6)]: Done  13 out of  16 | elapsed:   53.1s remaining:   12.2s
# [Parallel(n_jobs=6)]: Done  14 out of  16 | elapsed:   53.4s remaining:    7.6s
# [Parallel(n_jobs=6)]: Done  16 out of  16 | elapsed:   57.3s finished
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=6)]: Done   2 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=6)]: Done   3 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=6)]: Done   4 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=6)]: Done   5 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=6)]: Done   6 out of  16 | elapsed:   19.9s remaining:   33.2s
# [Parallel(n_jobs=6)]: Done   7 out of  16 | elapsed:   36.6s remaining:   47.1s
# [Parallel(n_jobs=6)]: Done   8 out of  16 | elapsed:   37.0s remaining:   37.0s
# [Parallel(n_jobs=6)]: Done   9 out of  16 | elapsed:   37.1s remaining:   28.9s
# [Parallel(n_jobs=6)]: Done  10 out of  16 | elapsed:   40.2s remaining:   24.1s
# [Parallel(n_jobs=6)]: Done  11 out of  16 | elapsed:   40.8s remaining:   18.5s
# [Parallel(n_jobs=6)]: Done  12 out of  16 | elapsed:   41.2s remaining:   13.7s
# [Parallel(n_jobs=6)]: Done  13 out of  16 | elapsed:   54.0s remaining:   12.5s
# [Parallel(n_jobs=6)]: Done  14 out of  16 | elapsed:   54.4s remaining:    7.8s
# [Parallel(n_jobs=6)]: Done  16 out of  16 | elapsed:   57.7s finished
# ...done
# Creating noise...

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 5))
im = ax.imshow(
    noise_lc[..., iz],
    extent=(0, box_length, 0, box_length),
    origin='lower', cmap='Greys', aspect='auto'
    )
ax.set_xlabel(r'$x$ [Mpc]')
ax.set_ylabel(r'$y$ [Mpc]')
plt.colorbar(im, label=r'$\delta T_b$ [mK]')
ax.set_title(rf'Noise @ $z={redshifts[iz]:.1f}$')
fig.tight_layout()

# %%
# combine noise and cosmological signal
noisy_lc = noise_lc + t2c.subtract_mean_signal(lc, los_axis=2)
# apply beam smoothing
dt_obs, zs_obs = t2c.smooth_lightcone(
    noisy_lc, 
    redshifts, 
    box_size_mpc=box_length,
    max_baseline=bmax,
)
# Out:
# 100%|██████████| 128/128 [00:01<00:00, 121.43it/s]

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 5))
im = ax.imshow(
    dt_obs[..., iz],
    extent=(0, box_length, 0, box_length),
    origin='lower', cmap='RdBu_r', aspect='auto',
    # vmin=-np.max(np.abs(lc[..., iz])), vmax=np.max(np.abs(lc[..., iz])),
    )
xi = np.linspace(0, box_length, ngrid)
ax.contour(xi, xi, lc[...,iz], levels=[1e-4], cmap="RdBu_r")
ax.set_xlabel(r'$x$ [Mpc]')
ax.set_ylabel(r'$y$ [Mpc]')
plt.colorbar(im, label=r'$\delta T_b$ [mK]')
ax.set_title(rf'Observed signal @ $z={redshifts[iz]:.1f}$')
fig.tight_layout()

# %% [markdown]
# ## Power spectrum

# %%
# Power spectra
nbins = 15
k_nyquist = np.pi/box_length*ngrid
# Fiducial 
ps_clean, ks = t2c.power_spectrum_1d(lc, kbins=15, box_dims=box_length_list)
ps_obs, ks = t2c.power_spectrum_1d(dt_obs, kbins=15, box_dims=box_length_list)
ps_noise, ks = t2c.power_spectrum_1d(noise_lc, kbins=15, box_dims=box_length_list)

# %%
fig, ax = plt.subplots()
ax.loglog(ks[ks<k_nyquist/2], ps_clean[ks<k_nyquist/2]*ks[ks<k_nyquist/2]**3/2/np.pi**2, lw=1., marker='.', label='Cosmological signal')
ax.loglog(ks[ks<k_nyquist/2], ps_noise[ks<k_nyquist/2]*ks[ks<k_nyquist/2]**3/2/np.pi**2, lw=1., marker='.', label='Noise')
ax.loglog(ks[ks<k_nyquist/2], ps_obs[ks<k_nyquist/2]*ks[ks<k_nyquist/2]**3/2/np.pi**2, lw=1., marker='.', label='Observed')
ax.set_ylabel(r'$\Delta^2_{21}(k)$ [mK$^2$]')
ax.set_xlabel(r'$k$ [Mpc$^{-1}$]')
plt.legend(frameon=False)
# plt.ylim(1e3, 1e8)
